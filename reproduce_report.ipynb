# %% [markdown]
# # Reproduce Final Report
#
# Run this notebook from top to bottom to reproduce `ECC3479 Final Report epie0003.pdf`.
#
# **Pipeline:**
# 1. `build_draft2.py` — assembles `docs/Report/Draft 2.ipynb` from the section notebooks
# 2. `export_pdf2.py` — executes the assembled notebook and exports it to `docs/Report/Draft 2.pdf`
# 3. Copies `Draft 2.pdf` to `ECC3479 Final Report epie0003.pdf`
#
# **Requirements:** `ecc3479-venv` Jupyter kernel, Playwright Chromium (`playwright install chromium`).

# %%
# Step 1: Assemble Draft 2.ipynb from section notebooks
# %run build_draft2.py

# %%
# Step 2: Execute notebook and export to PDF
# %run export_pdf2.py

# %%
# Step 3: Copy to submitted filename
import shutil
from pathlib import Path

src  = Path('docs/Report/Draft 2.pdf')
dest = Path('docs/Report/ECC3479 Final Report epie0003.pdf')
shutil.copy2(src, dest)
print(f'Reproduced: {dest} ({dest.stat().st_size // 1024} KB)')
